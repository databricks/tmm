// %%
package com.databricks.dais2025

/**
 * City locations mapping for environmental sensor data generation
 * 
 * Contains 64 cities worldwide, each with 3 specific locations
 */
object CityLocations {

  val cityLocations: Map[String, Seq[String]] = Map(
    "New York" -> Seq("NYC-HQ", "NYC-Downtown", "NYC-Midtown"),
    "London" -> Seq("LDN-City", "LDN-Canary", "LDN-West"),
    "Tokyo" -> Seq("TKY-Shibuya", "TKY-Shinjuku", "TKY-Ginza"),
    "Sydney" -> Seq("SYD-CBD", "SYD-North", "SYD-Harbor"),
    "Paris" -> Seq("PAR-Center", "PAR-Defense", "PAR-East"),
    "Berlin" -> Seq("BER-Mitte", "BER-Kreuzberg", "BER-Charlottenburg"),
    "San Francisco" -> Seq("SF-Downtown", "SF-Mission", "SF-SOMA"),
    "Singapore" -> Seq("SGP-Orchard", "SGP-Marina", "SGP-ClarkeQuay"),
    "Toronto" -> Seq("TOR-Downtown", "TOR-NorthYork", "TOR-Scarborough"),
    "Dubai" -> Seq("DXB-Marina", "DXB-Downtown", "DXB-Jumeirah"),
    "Mumbai" -> Seq("MUM-Bandra", "MUM-Andheri", "MUM-Colaba"),
    "Johannesburg" -> Seq("JHB-Sandton", "JHB-Rosebank", "JHB-Maboneng"),
    "Mexico City" -> Seq("MEX-Polanco", "MEX-Condesa", "MEX-Coyoacan"),
    "Moscow" -> Seq("MSK-Center", "MSK-Arbat", "MSK-Tverskaya"),
    "Hong Kong" -> Seq("HK-Central", "HK-Kowloon", "HK-TsimShaTsui"),
    "Los Angeles" -> Seq("LA-Hollywood", "LA-Downtown", "LA-SantaMonica"),
    "Chicago" -> Seq("CHI-Loop", "CHI-RiverNorth", "CHI-WestLoop"),
    "Shanghai" -> Seq("SHA-Pudong", "SHA-Puxi", "SHA-Bund"),
    "Seoul" -> Seq("SEL-Gangnam", "SEL-Hongdae", "SEL-Myeongdong"),
    "Amsterdam" -> Seq("AMS-Center", "AMS-Zuidas", "AMS-Noord"),
    "Madrid" -> Seq("MAD-Centro", "MAD-Salamanca", "MAD-Chamberi"),
    "Barcelona" -> Seq("BCN-Gothic", "BCN-Eixample", "BCN-Gracia"),
    "Rome" -> Seq("ROM-Centro", "ROM-Trastevere", "ROM-Prati"),
    "Milan" -> Seq("MIL-Duomo", "MIL-Porta", "MIL-Brera"),
    "Istanbul" -> Seq("IST-Beyoglu", "IST-Besiktas", "IST-Kadikoy"),
    "Bangkok" -> Seq("BKK-Sukhumvit", "BKK-Silom", "BKK-Siam"),
    "Jakarta" -> Seq("JKT-SCBD", "JKT-Menteng", "JKT-Kemang"),
    "Manila" -> Seq("MNL-Makati", "MNL-BGC", "MNL-Ortigas"),
    "Kuala Lumpur" -> Seq("KUL-KLCC", "KUL-Bukit", "KUL-Bangsar"),
    "Melbourne" -> Seq("MEL-CBD", "MEL-Southbank", "MEL-Docklands"),
    "Brisbane" -> Seq("BNE-CBD", "BNE-Fortitude", "BNE-Southbank"),
    "Auckland" -> Seq("AKL-CBD", "AKL-Viaduct", "AKL-Ponsonby"),
    "Wellington" -> Seq("WLG-CBD", "WLG-Lambton", "WLG-Waterfront"),
    "Montreal" -> Seq("MTL-Downtown", "MTL-Plateau", "MTL-OldPort"),
    "Vancouver" -> Seq("YVR-Downtown", "YVR-Yaletown", "YVR-Gastown"),
    "Seattle" -> Seq("SEA-Downtown", "SEA-Capitol", "SEA-SouthLake"),
    "Boston" -> Seq("BOS-BackBay", "BOS-Seaport", "BOS-Financial"),
    "Washington" -> Seq("WAS-Downtown", "WAS-Georgetown", "WAS-Capitol"),
    "Atlanta" -> Seq("ATL-Midtown", "ATL-Buckhead", "ATL-Downtown"),
    "Miami" -> Seq("MIA-Brickell", "MIA-Downtown", "MIA-Wynwood"),
    "Dallas" -> Seq("DAL-Downtown", "DAL-Uptown", "DAL-Arts"),
    "Houston" -> Seq("HOU-Downtown", "HOU-Midtown", "HOU-Galleria"),
    "Phoenix" -> Seq("PHX-Downtown", "PHX-Midtown", "PHX-Tempe"),
    "Denver" -> Seq("DEN-Downtown", "DEN-LoDo", "DEN-CapitolHill"),
    "Austin" -> Seq("AUS-Downtown", "AUS-Domain", "AUS-SouthCongress"),
    "Philadelphia" -> Seq("PHL-Center", "PHL-University", "PHL-Rittenhouse"),
    "San Diego" -> Seq("SAN-Downtown", "SAN-Gaslamp", "SAN-LittleItaly"),
    "Portland" -> Seq("PDX-Downtown", "PDX-Pearl", "PDX-Eastside"),
    "Copenhagen" -> Seq("CPH-Center", "CPH-Nyhavn", "CPH-Vesterbro"),
    "Stockholm" -> Seq("STO-Gamla", "STO-Norrmalm", "STO-Ostermalm"),
    "Oslo" -> Seq("OSL-Sentrum", "OSL-Aker", "OSL-Frogner"),
    "Helsinki" -> Seq("HEL-Center", "HEL-Kamppi", "HEL-Kallio"),
    "Brussels" -> Seq("BRU-Center", "BRU-European", "BRU-Ixelles"),
    "Vienna" -> Seq("VIE-Innere", "VIE-Leopoldstadt", "VIE-Mariahilf"),
    "Zurich" -> Seq("ZRH-Center", "ZRH-West", "ZRH-Nord"),
    "Geneva" -> Seq("GVA-Center", "GVA-Eaux", "GVA-Plainpalais"),
    "Lisbon" -> Seq("LIS-Baixa", "LIS-Chiado", "LIS-Parque"),
    "Dublin" -> Seq("DUB-Center", "DUB-Docklands", "DUB-Temple"),
    "Edinburgh" -> Seq("EDI-OldTown", "EDI-NewTown", "EDI-Leith"),
    "Manchester" -> Seq("MAN-Center", "MAN-Northern", "MAN-Spinningfields"),
    "Prague" -> Seq("PRG-OldTown", "PRG-NewTown", "PRG-Vinohrady"),
    "Warsaw" -> Seq("WAW-Center", "WAW-Mokotow", "WAW-Wola"),
    "Budapest" -> Seq("BUD-Pest", "BUD-Buda", "BUD-Leopold"),
    "Athens" -> Seq("ATH-Syntagma", "ATH-Kolonaki", "ATH-Plaka")
  )
}
